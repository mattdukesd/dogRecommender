# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
my_str=""

# %%
html = requests.get('http://petadoption.ocpetinfo.com/LostFound/FoundList.asp?type=Dog')
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(html.text, 'html.parser')
# Examine the results, then determine element that contains sought info
# results are returned as an iterable list      
                   
table=soup.find_all('table',class_="tblpetbrdr")

# %%
for tr in soup.find_all('tr'):
    link=tr.find('a', {'href': re.compile('LFShowImage.asp?')})

# %%
str_list=""

for tab in table:
       str_list+=tab.text

# %%
images = soup.findAll('img')
img_list=[]
link_list=[]
for image in images:
    img_list.append(image['src'])

# %%
unwanted = {"/ocgov/img/blank.gif","images/camera.gif","images/back-to-search.gif"}
img_list = [e for e in img_list if e not in unwanted]

# %%
img_list

for link in img_list:
    
    link_list.append(link.replace("../","http://petadoption.ocpetinfo.com/"))

# %%
link_list
# Out:
# ['http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1086965',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571195',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1569453',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1507288',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1569513',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1569514',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1569516',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1569517',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1569518',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571295',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571506',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571719',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571920',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571853',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571799',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571514',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571533',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571539',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571219',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571368',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571396',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1485437',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571982',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1572090',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571603',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571605',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571455',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571927',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1560750',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1570265',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571522',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571201',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1566935',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1570105',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571199',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1566279',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1565185',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571183',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571453',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571357',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1572026',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571677',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571452',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1476015',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571913',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1572033',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571961',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571802',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571599',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571394',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1570498',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1526921',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1545265',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1560635',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1563472',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1564142',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1564184',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1564958',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1566233',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1570276',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1568806',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1572043',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1572044',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1572047',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1572017',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1569656',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1568356',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1567053',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1567327',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1283769',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1232105',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1283634',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571194',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1568093',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571804',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571917',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1571359',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1490547',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1570936',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1570479',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1569452',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1568134',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1565156',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1570699',
#  'http://petadoption.ocpetinfo.com/rescuetrack/servicethumb.php?tab=lost&detailid=A1562494']

# %%
newStr =str_list .split('\n')
newstr=[x for x in newStr if x!='\r' ]
newstr=[x for x in newstr if x!='\n']
newstr=[x for x in newstr if x!='']
newstr=[s.replace('                  ', '') for s in newstr] 
newstr = [s.replace('\r', '') for s in newstr]
newstr=[s.replace('\xa0', ' ') for s in newstr] 
newstr=[s.replace('\xa0', ' ') for s in newstr] 

newstr=[s.replace('              ', '') for s in newstr]

# %%
for j in range(len(newstr)-1):
    if (newstr[j]==' ' and newstr[j+1]!=''):
         newstr[j]="*"
newstr=[x for x in newstr if x!='*']
newstr=[x for x in newstr if x!=' ']
newstr=[x for x in newstr if x!='            ']
newstr=[x for x in newstr if x!='\t\t\t\t  ']

# %%
composite_list = [newstr[x:x+8] for x in range(0, len(newstr),8)]

# %%
dt=pd.DataFrame(composite_list, columns = composite_list[0])
dt
# Out:
#           ID  Sex             Age     Weight             Color  \
# 0         ID  Sex             Age     Weight             Color
# 1   A1086965    M         9 Years   84.2 LBS        GRAY WHITE
# 2   A1571195    M         2 Years   50.4 LBS             WHITE
# 3   A1569453    N         6 Years   60.0 LBS        BLUE MERLE
# 4   A1507288    S         2 Years                     TRICOLOR
# 5   A1569513    F         3 Years   15.0 LBS       BLACK WHITE
# 6   A1569514    F         4 Weeks    2.3 LBS               TAN
# 7   A1569516    M         4 Weeks    2.8 LBS             BROWN
# 8   A1569517    M         4 Weeks    1.9 LBS             WHITE
# 9   A1569518    M         4 Weeks    2.5 LBS            BLONDE
# 10  A1571295    M         4 Years   58.0 LBS       WHITE BLACK
# 11  A1571506    N         3 Years   26.0 LBS         RED WHITE
# 12  A1571719    F         6 Years   60.4 LBS  WHITE BR BRINDLE
# 13  A1571920    M         3 Years   17.1 LBS       BLACK WHITE
# 14  A1571853    M         2 Years   11.3 LBS         BLACK TAN
# 15  A1571799    F         4 Years    8.7 LBS               RED
# 16  A1571514    F        6 Months    8.2 LBS      BLONDE WHITE
# 17  A1571533    F        10 Years    6.7 LBS         BROWN TAN
# 18  A1571539    M         6 Years    9.3 LBS       BLACK BROWN
# 19  A1571219    F         3 Years   11.9 LBS         RED WHITE
# 20  A1571368    M         3 Years   12.0 LBS            YELLOW
# 21  A1571396    M          1 Year                 BLONDE WHITE
# 22  A1485437    N         6 Years   14.0 LBS         WHITE TAN
# 23  A1571982    M         4 Years                        BLACK
# 24  A1572090    N         4 Years    8.8 LBS         TAN WHITE
# 25  A1571603    M         2 Years                        WHITE
# 26  A1571605    F         4 Years   10.0 LBS        GRAY WHITE
# 27  A1571455    N         4 Years   15.4 LBS       BROWN WHITE
# 28  A1571927    M         7 Years    9.5 LBS     CHOCOLATE TAN
# 29  A1560750    M         3 Years   13.3 LBS               RED
# ..       ...  ...             ...        ...               ...
# 56  A1564142    M         5 Years   74.9 LBS       BROWN WHITE
# 57  A1564184    N         3 Years   65.0 LBS        FAWN WHITE
# 58  A1564958    N         3 Years   65.0 LBS         TAN WHITE
# 59  A1566233    N         3 Years   72.0 LBS        BLUE WHITE
# 60  A1570276    M         2 Years   81.0 LBS        BLUE WHITE
# 61  A1568806    F         4 Years   61.0 LBS              BLUE
# 62  A1572043    F         2 Years                    WHITE TAN
# 63  A1572044    M         2 Years                   WHITE GRAY
# 64  A1572047    M         2 Years   65.9 LBS             BROWN
# 65  A1572017    M         2 Years                  BLACK WHITE
# 66  A1569656    N         4 Years   83.0 LBS        WHITE GRAY
# 67  A1568356    N         4 Years   53.0 LBS       BLACK WHITE
# 68  A1567053    S         2 Years   56.0 LBS  BR BRINDLE WHITE
# 69  A1567327    M  1 Year 1 Month   69.0 LBS         TAN WHITE
# 70  A1283769    M          4 Year   76.0 LBS        BLUE WHITE
# 71  A1232105    N         8 Years   71.4 LBS        FAWN WHITE
# 72  A1283634    N         7 Years   25.5 LBS             WHITE
# 73  A1571194    M         3 Years    8.9 LBS             WHITE
# 74  A1568093    M  1 Year 1 Month    5.3 LBS         WHITE TAN
# 75  A1571804    M         5 Years   12.4 LBS             WHITE
# 76  A1571917    F         5 Years   12.9 LBS             WHITE
# 77  A1571359    M         2 Years   13.4 LBS         BLACK TAN
# 78  A1490547    M          3 Year   10.2 LBS             BLACK
# 79  A1570936    M         9 Years   27.0 LBS         RED WHITE
# 80  A1570479    F         4 Years   12.0 LBS       BLACK WHITE
# 81  A1569452    F         2 Years   49.6 LBS       BLACK WHITE
# 82  A1568134    N         4 Years   44.0 LBS             WHITE
# 83  A1565156    N         5 Years   57.0 LBS       BLACK WHITE
# 84  A1570699    M         2 Years   48.7 LBS      BLK/WHT GRAY
# 85  A1562494    N         4 Years  117.0 LBS          TRICOLOR
#
#                      Breed  Intake Jurisdiction  Intake Date
# 0                    Breed  Intake Jurisdiction  Intake Date
# 1       ALASK MALAMUTE MIX       HUNTINGTON BCH    4/20/2018
# 2            ALASKAN HUSKY              CYPRESS    4/16/2018
# 3          AUST CATTLE DOG       HUNTINGTON BCH     4/4/2018
# 4                   BEAGLE              ANAHEIM    4/18/2018
# 5               BEAGLE MIX            SANTA ANA     4/4/2018
# 6               BEAGLE MIX            SANTA ANA     4/4/2018
# 7               BEAGLE MIX            SANTA ANA     4/4/2018
# 8               BEAGLE MIX            SANTA ANA     4/4/2018
# 9               BEAGLE MIX            SANTA ANA     4/4/2018
# 10              BEAGLE MIX              ANAHEIM    4/16/2018
# 11          BORDER TERRIER          LAKE FOREST    4/18/2018
# 12            BULL TERRIER               TUSTIN    4/19/2018
# 13           CAIRN TERRIER            SANTA ANA    4/20/2018
# 14            CHIHUAHUA LH            SANTA ANA    4/20/2018
# 15            CHIHUAHUA SH            SANTA ANA    4/19/2018
# 16            CHIHUAHUA SH               TUSTIN    4/18/2018
# 17            CHIHUAHUA SH            SANTA ANA    4/18/2018
# 18            CHIHUAHUA SH            SANTA ANA    4/18/2018
# 19            CHIHUAHUA SH            SANTA ANA    4/16/2018
# 20            CHIHUAHUA SH            FULLERTON    4/17/2018
# 21            CHIHUAHUA SH            SANTA ANA    4/17/2018
# 22            CHIHUAHUA SH              ANAHEIM    4/20/2018
# 23            CHIHUAHUA SH            ORANGE CO    4/20/2018
# 24            CHIHUAHUA SH           VILLA PARK    4/21/2018
# 25  CHIHUAHUA SH DACHSHUND            SANTA ANA    4/18/2018
# 26        CHIHUAHUA SH MIX          LAKE FOREST    4/18/2018
# 27        CHIHUAHUA SH MIX              CYPRESS    4/17/2018
# 28        CHIHUAHUA SH MIX              ANAHEIM    4/20/2018
# 29        CHIHUAHUA SH MIX         SANTA ANA CO    1/29/2018
# ..                     ...                  ...          ...
# 56                PIT BULL            SANTA ANA    2/23/2018
# 57                PIT BULL            SANTA ANA    2/23/2018
# 58                PIT BULL            SANTA ANA    4/18/2018
# 59                PIT BULL            SANTA ANA    3/11/2018
# 60                PIT BULL            SANTA ANA     4/9/2018
# 61                PIT BULL            SANTA ANA    3/30/2018
# 62                PIT BULL            SANTA ANA    4/20/2018
# 63                PIT BULL            SANTA ANA    4/20/2018
# 64                PIT BULL       HUNTINGTON BCH    4/20/2018
# 65            PIT BULL MIX            FULLERTON    4/20/2018
# 66            PIT BULL MIX            FULLERTON     4/5/2018
# 67            PIT BULL MIX       HUNTINGTON BCH    3/27/2018
# 68            PIT BULL MIX            ORANGE CO    3/19/2018
# 69            PIT BULL MIX              ANAHEIM    3/21/2018
# 70            PIT BULL MIX              ANAHEIM    4/16/2018
# 71            PIT BULL MIX        ORANGE CO FCC    1/22/2018
# 72              POODLE MIN               ORANGE    4/20/2018
# 73              POODLE MIN          YORBA LINDA    4/16/2018
# 74      POODLE MIN MALTESE               TUSTIN    3/26/2018
# 75          POODLE MIN MIX              ANAHEIM    4/19/2018
# 76          POODLE MIN MIX            FULLERTON    4/20/2018
# 77           PUG DACHSHUND              ANAHEIM    4/17/2018
# 78         RAT TERRIER MIX            SILVERADO    4/13/2018
# 79               SHIBA INU              ANAHEIM    4/13/2018
# 80                SHIH TZU              ANAHEIM    4/10/2018
# 81          SIBERIAN HUSKY              ANAHEIM     4/4/2018
# 82          SIBERIAN HUSKY            SANTA ANA     4/9/2018
# 83          SIBERIAN HUSKY              ANAHEIM     3/3/2018
# 84          SIBERIAN HUSKY              ANAHEIM    4/11/2018
# 85          ST BERNARD RGH            FULLERTON    2/21/2018
#
# [86 rows x 8 columns]

# %%
dt=dt.drop([0])
dt['link']=link_list
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85 entries, 1 to 85
# Data columns (total 9 columns):
# ID                     85 non-null object
# Sex                    85 non-null object
# Age                    85 non-null object
# Weight                 85 non-null object
# Color                  85 non-null object
# Breed                  85 non-null object
# Intake Jurisdiction    85 non-null object
# Intake Date            85 non-null object
# link                   85 non-null object
# dtypes: object(9)
# memory usage: 6.6+ KB

# %%
dt
# Out:
#           ID Sex             Age     Weight             Color  \
# 1   A1086965   M         9 Years   84.2 LBS        GRAY WHITE
# 2   A1571195   M         2 Years   50.4 LBS             WHITE
# 3   A1569453   N         6 Years   60.0 LBS        BLUE MERLE
# 4   A1507288   S         2 Years                     TRICOLOR
# 5   A1569513   F         3 Years   15.0 LBS       BLACK WHITE
# 6   A1569514   F         4 Weeks    2.3 LBS               TAN
# 7   A1569516   M         4 Weeks    2.8 LBS             BROWN
# 8   A1569517   M         4 Weeks    1.9 LBS             WHITE
# 9   A1569518   M         4 Weeks    2.5 LBS            BLONDE
# 10  A1571295   M         4 Years   58.0 LBS       WHITE BLACK
# 11  A1571506   N         3 Years   26.0 LBS         RED WHITE
# 12  A1571719   F         6 Years   60.4 LBS  WHITE BR BRINDLE
# 13  A1571920   M         3 Years   17.1 LBS       BLACK WHITE
# 14  A1571853   M         2 Years   11.3 LBS         BLACK TAN
# 15  A1571799   F         4 Years    8.7 LBS               RED
# 16  A1571514   F        6 Months    8.2 LBS      BLONDE WHITE
# 17  A1571533   F        10 Years    6.7 LBS         BROWN TAN
# 18  A1571539   M         6 Years    9.3 LBS       BLACK BROWN
# 19  A1571219   F         3 Years   11.9 LBS         RED WHITE
# 20  A1571368   M         3 Years   12.0 LBS            YELLOW
# 21  A1571396   M          1 Year                 BLONDE WHITE
# 22  A1485437   N         6 Years   14.0 LBS         WHITE TAN
# 23  A1571982   M         4 Years                        BLACK
# 24  A1572090   N         4 Years    8.8 LBS         TAN WHITE
# 25  A1571603   M         2 Years                        WHITE
# 26  A1571605   F         4 Years   10.0 LBS        GRAY WHITE
# 27  A1571455   N         4 Years   15.4 LBS       BROWN WHITE
# 28  A1571927   M         7 Years    9.5 LBS     CHOCOLATE TAN
# 29  A1560750   M         3 Years   13.3 LBS               RED
# 30  A1570265   F         5 Years   47.5 LBS         WHITE TAN
# ..       ...  ..             ...        ...               ...
# 56  A1564142   M         5 Years   74.9 LBS       BROWN WHITE
# 57  A1564184   N         3 Years   65.0 LBS        FAWN WHITE
# 58  A1564958   N         3 Years   65.0 LBS         TAN WHITE
# 59  A1566233   N         3 Years   72.0 LBS        BLUE WHITE
# 60  A1570276   M         2 Years   81.0 LBS        BLUE WHITE
# 61  A1568806   F         4 Years   61.0 LBS              BLUE
# 62  A1572043   F         2 Years                    WHITE TAN
# 63  A1572044   M         2 Years                   WHITE GRAY
# 64  A1572047   M         2 Years   65.9 LBS             BROWN
# 65  A1572017   M         2 Years                  BLACK WHITE
# 66  A1569656   N         4 Years   83.0 LBS        WHITE GRAY
# 67  A1568356   N         4 Years   53.0 LBS       BLACK WHITE
# 68  A1567053   S         2 Years   56.0 LBS  BR BRINDLE WHITE
# 69  A1567327   M  1 Year 1 Month   69.0 LBS         TAN WHITE
# 70  A1283769   M          4 Year   76.0 LBS        BLUE WHITE
# 71  A1232105   N         8 Years   71.4 LBS        FAWN WHITE
# 72  A1283634   N         7 Years   25.5 LBS             WHITE
# 73  A1571194   M         3 Years    8.9 LBS             WHITE
# 74  A1568093   M  1 Year 1 Month    5.3 LBS         WHITE TAN
# 75  A1571804   M         5 Years   12.4 LBS             WHITE
# 76  A1571917   F         5 Years   12.9 LBS             WHITE
# 77  A1571359   M         2 Years   13.4 LBS         BLACK TAN
# 78  A1490547   M          3 Year   10.2 LBS             BLACK
# 79  A1570936   M         9 Years   27.0 LBS         RED WHITE
# 80  A1570479   F         4 Years   12.0 LBS       BLACK WHITE
# 81  A1569452   F         2 Years   49.6 LBS       BLACK WHITE
# 82  A1568134   N         4 Years   44.0 LBS             WHITE
# 83  A1565156   N         5 Years   57.0 LBS       BLACK WHITE
# 84  A1570699   M         2 Years   48.7 LBS      BLK/WHT GRAY
# 85  A1562494   N         4 Years  117.0 LBS          TRICOLOR
#
#                      Breed Intake Jurisdiction Intake Date  \
# 1       ALASK MALAMUTE MIX      HUNTINGTON BCH   4/20/2018
# 2            ALASKAN HUSKY             CYPRESS   4/16/2018
# 3          AUST CATTLE DOG      HUNTINGTON BCH    4/4/2018
# 4                   BEAGLE             ANAHEIM   4/18/2018
# 5               BEAGLE MIX           SANTA ANA    4/4/2018
# 6               BEAGLE MIX           SANTA ANA    4/4/2018
# 7               BEAGLE MIX           SANTA ANA    4/4/2018
# 8               BEAGLE MIX           SANTA ANA    4/4/2018
# 9               BEAGLE MIX           SANTA ANA    4/4/2018
# 10              BEAGLE MIX             ANAHEIM   4/16/2018
# 11          BORDER TERRIER         LAKE FOREST   4/18/2018
# 12            BULL TERRIER              TUSTIN   4/19/2018
# 13           CAIRN TERRIER           SANTA ANA   4/20/2018
# 14            CHIHUAHUA LH           SANTA ANA   4/20/2018
# 15            CHIHUAHUA SH           SANTA ANA   4/19/2018
# 16            CHIHUAHUA SH              TUSTIN   4/18/2018
# 17            CHIHUAHUA SH           SANTA ANA   4/18/2018
# 18            CHIHUAHUA SH           SANTA ANA   4/18/2018
# 19            CHIHUAHUA SH           SANTA ANA   4/16/2018
# 20            CHIHUAHUA SH           FULLERTON   4/17/2018
# 21            CHIHUAHUA SH           SANTA ANA   4/17/2018
# 22            CHIHUAHUA SH             ANAHEIM   4/20/2018
# 23            CHIHUAHUA SH           ORANGE CO   4/20/2018
# 24            CHIHUAHUA SH          VILLA PARK   4/21/2018
# 25  CHIHUAHUA SH DACHSHUND           SANTA ANA   4/18/2018
# 26        CHIHUAHUA SH MIX         LAKE FOREST   4/18/2018
# 27        CHIHUAHUA SH MIX             CYPRESS   4/17/2018
# 28        CHIHUAHUA SH MIX             ANAHEIM   4/20/2018
# 29        CHIHUAHUA SH MIX        SANTA ANA CO   1/29/2018
# 30         CHINESE SHARPEI           FULLERTON    4/9/2018
# ..                     ...                 ...         ...
# 56                PIT BULL           SANTA ANA   2/23/2018
# 57                PIT BULL           SANTA ANA   2/23/2018
# 58                PIT BULL           SANTA ANA   4/18/2018
# 59                PIT BULL           SANTA ANA   3/11/2018
# 60                PIT BULL           SANTA ANA    4/9/2018
# 61                PIT BULL           SANTA ANA   3/30/2018
# 62                PIT BULL           SANTA ANA   4/20/2018
# 63                PIT BULL           SANTA ANA   4/20/2018
# 64                PIT BULL      HUNTINGTON BCH   4/20/2018
# 65            PIT BULL MIX           FULLERTON   4/20/2018
# 66            PIT BULL MIX           FULLERTON    4/5/2018
# 67            PIT BULL MIX      HUNTINGTON BCH   3/27/2018
# 68            PIT BULL MIX           ORANGE CO   3/19/2018
# 69            PIT BULL MIX             ANAHEIM   3/21/2018
# 70            PIT BULL MIX             ANAHEIM   4/16/2018
# 71            PIT BULL MIX       ORANGE CO FCC   1/22/2018
# 72              POODLE MIN              ORANGE   4/20/2018
# 73              POODLE MIN         YORBA LINDA   4/16/2018
# 74      POODLE MIN MALTESE              TUSTIN   3/26/2018
# 75          POODLE MIN MIX             ANAHEIM   4/19/2018
# 76          POODLE MIN MIX           FULLERTON   4/20/2018
# 77           PUG DACHSHUND             ANAHEIM   4/17/2018
# 78         RAT TERRIER MIX           SILVERADO   4/13/2018
# 79               SHIBA INU             ANAHEIM   4/13/2018
# 80                SHIH TZU             ANAHEIM   4/10/2018
# 81          SIBERIAN HUSKY             ANAHEIM    4/4/2018
# 82          SIBERIAN HUSKY           SANTA ANA    4/9/2018
# 83          SIBERIAN HUSKY             ANAHEIM    3/3/2018
# 84          SIBERIAN HUSKY             ANAHEIM   4/11/2018
# 85          ST BERNARD RGH           FULLERTON   2/21/2018
#
#                                                  link
# 1   http://petadoption.ocpetinfo.com/rescuetrack/s...
# 2   http://petadoption.ocpetinfo.com/rescuetrack/s...
# 3   http://petadoption.ocpetinfo.com/rescuetrack/s...
# 4   http://petadoption.ocpetinfo.com/rescuetrack/s...
# 5   http://petadoption.ocpetinfo.com/rescuetrack/s...
# 6   http://petadoption.ocpetinfo.com/rescuetrack/s...
# 7   http://petadoption.ocpetinfo.com/rescuetrack/s...
# 8   http://petadoption.ocpetinfo.com/rescuetrack/s...
# 9   http://petadoption.ocpetinfo.com/rescuetrack/s...
# 10  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 11  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 12  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 13  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 14  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 15  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 16  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 17  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 18  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 19  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 20  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 21  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 22  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 23  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 24  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 25  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 26  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 27  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 28  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 29  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 30  http://petadoption.ocpetinfo.com/rescuetrack/s...
# ..                                                ...
# 56  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 57  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 58  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 59  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 60  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 61  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 62  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 63  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 64  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 65  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 66  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 67  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 68  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 69  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 70  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 71  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 72  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 73  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 74  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 75  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 76  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 77  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 78  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 79  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 80  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 81  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 82  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 83  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 84  http://petadoption.ocpetinfo.com/rescuetrack/s...
# 85  http://petadoption.ocpetinfo.com/rescuetrack/s...
#
# [85 rows x 9 columns]

# %%
dt.to_csv("found_list.csv")
