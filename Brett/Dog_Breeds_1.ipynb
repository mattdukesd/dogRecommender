# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd
data_file = "Dog_Breed_Links.csv"

data_file_pd = pd.read_csv(data_file)
ins=pd.DataFrame(data_file_pd)
my_dict={'breed': [], 'characteristic': [], 'rating':[]}

# %%
for row in ins.iterrows():

    # URL of Python reddit
    url = row[1][1]
    breed=row[1][0]
    # Retrieve page with the requests module
    html = requests.get(url)
    # Create BeautifulSoup object; parse with 'html.parser'
    soup = BeautifulSoup(html.text, 'html.parser')

    # Examine the results, then determine element that contains sought info
    # results are returned as an iterable list
    results = soup.find_all('div', class_='js-list-item item-expandable-content default-border-bottom default-margin-bottom default-padding-bottom star-by-breed child-characteristic')
    for result in results:
    # Retrieve the thread title
        part=result.find('a', class_='js-list-item-trigger item-trigger more-info')
        characteris=part.find('span',class_='characteristic item-trigger-title')
        if(part):
            star=part.find('span',class_='star')
       
            my_dict["breed"].append(breed)
            my_dict["characteristic"].append(characteris.text)
            my_dict["rating"].append(star.text)
print(my_dict)
# Out:
# {'breed': ['Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Affenpinscher', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Afghan Hound', 'Airedale Terrier', 'Airedale Terrier', 'Airedale Terrier', 'Airedale Terrier', 'Airedale Terrier', 'Airedale Terrier', 'Airedale
# ...

# %%
df=pd.DataFrame(my_dict)

# %%
df.head()
# Out:
#            breed                   characteristic rating
# 0  Affenpinscher  Adapts Well to Apartment Living      5
# 1  Affenpinscher           Good For Novice Owners      4
# 2  Affenpinscher                Sensitivity Level      3
# 3  Affenpinscher            Tolerates Being Alone      1
# 4  Affenpinscher           Tolerates Cold Weather      3

# %%
df
# Out:
#                   breed                   characteristic rating
# 0         Affenpinscher  Adapts Well to Apartment Living      5
# 1         Affenpinscher           Good For Novice Owners      4
# 2         Affenpinscher                Sensitivity Level      3
# 3         Affenpinscher            Tolerates Being Alone      1
# 4         Affenpinscher           Tolerates Cold Weather      3
# 5         Affenpinscher            Tolerates Hot Weather      3
# 6         Affenpinscher         Affectionate with Family      5
# 7         Affenpinscher     Incredibly Kid Friendly Dogs      1
# 8         Affenpinscher                     Dog Friendly      4
# 9         Affenpinscher        Friendly Toward Strangers      3
# 10        Affenpinscher               Amount Of Shedding      1
# 11        Affenpinscher               Drooling Potential      1
# 12        Affenpinscher                    Easy To Groom      3
# 13        Affenpinscher                   General Health      4
# ...

# %%
df.to_csv("dog_breed.csv")
