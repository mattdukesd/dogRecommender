# %%
# Dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd
import re
my_str=""

# %%
html = requests.get('http://petadoption.ocpetinfo.com/LostFound/FoundList.asp?type=Dog')
# Create BeautifulSoup object; parse with 'html.parser'
soup = BeautifulSoup(html.text, 'html.parser')
# Examine the results, then determine element that contains sought info
# results are returned as an iterable list      
                   
table=soup.find_all('table',class_="tblpetbrdr")

# %%
for tr in soup.find_all('tr'):
    link=tr.find('a', {'href': re.compile('LFShowImage.asp?')})

# %%
str_list=""

for tab in table:
       str_list+=tab.text

# %%
images = soup.findAll('img')
img_list=[]
for image in images:
    img_list.append(image['src'])

# %%
unwanted = {"/ocgov/img/blank.gif","images/camera.gif","images/back-to-search.gif"}
img_list = [e for e in img_list if e not in unwanted]

# %%
img_list
# Out:
# ['../rescuetrack/servicethumb.php?tab=lost&detailid=A1570687',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1569847',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1569453',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1564440',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570772',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570777',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570780',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570658',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570906',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1560750',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1569513',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1569514',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1569516',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1569517',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1569518',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1568373',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570265',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570598',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1464021',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570978',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570778',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1566935',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570865',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570105',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570493',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570874',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1567904',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1566279',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1566721',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570336',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570380',
#  'images/no-photo.jpg',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1476015',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570866',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570783',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570648',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570433',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570498',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570398',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570276',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570775',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1487390',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1545265',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1558941',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1560635',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1566233',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1563472',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1564142',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1564184',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1568607',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1568806',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1569643',
#  'images/no-photo.jpg',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570861',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1569656',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1567053',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1567327',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1232105',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1541636',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570850',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570429',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1568093',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1490547',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570776',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570936',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570479',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570699',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1570981',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1568134',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1569452',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1562494',
#  '../rescuetrack/servicethumb.php?tab=lost&detailid=A1566722']

# %%
len(img_list)
# Out:
# 72

# %%
newStr =str_list .split('\n')
newstr=[x for x in newStr if x!='\r' ]
newstr=[x for x in newstr if x!='\n']
newstr=[x for x in newstr if x!='']
newstr=[s.replace('                  ', '') for s in newstr] 
newstr = [s.replace('\r', '') for s in newstr]
newstr=[s.replace('\xa0', ' ') for s in newstr] 
newstr=[s.replace('\xa0', ' ') for s in newstr] 

newstr=[s.replace('              ', '') for s in newstr]

# %%
for j in range(len(newstr)-1):
    if (newstr[j]==' ' and newstr[j+1]!=''):
         newstr[j]="*"
newstr=[x for x in newstr if x!='*']
newstr=[x for x in newstr if x!=' ']
newstr=[x for x in newstr if x!='            ']
newstr=[x for x in newstr if x!='\t\t\t\t  ']

# %%
composite_list = [newstr[x:x+8] for x in range(0, len(newstr),8)]

# %%
dt=pd.DataFrame(composite_list, columns = composite_list[0])
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72 entries, 0 to 71
# Data columns (total 8 columns):
# ID                     72 non-null object
# Sex                    72 non-null object
# Age                    72 non-null object
# Weight                 72 non-null object
# Color                  72 non-null object
# Breed                  72 non-null object
# Intake Jurisdiction    72 non-null object
# Intake Date            72 non-null object
# dtypes: object(8)
# memory usage: 4.6+ KB

# %%
dt=dt.drop([0])
dt
# Out:
#           ID Sex              Age     Weight             Color  \
# 1   A1570687   M  1 Year 7 Months                  BLACK WHITE
# 2   A1569847   M           1 Year   47.0 LBS       BLACK WHITE
# 3   A1569453   N          6 Years   60.0 LBS        BLUE MERLE
# 4   A1564440   M          3 Years   76.0 LBS       BLACK WHITE
# 5   A1570772   M          4 Years   18.0 LBS         TAN WHITE
# 6   A1570777   F          3 Years   25.2 LBS             BROWN
# 7   A1570780   F          6 Years    6.2 LBS  BR BRINDLE WHITE
# 8   A1570658   M          3 Years    3.8 LBS               TAN
# 9   A1570906   F          2 Years    6.6 LBS             BROWN
# 10  A1560750   M          3 Years   13.3 LBS               RED
# 11  A1569513   F          3 Years   12.9 LBS       BLACK WHITE
# 12  A1569514   F              25D    1.0 LBS               TAN
# 13  A1569516   M              25D    1.0 LBS             BROWN
# 14  A1569517   M              25D    1.0 LBS             WHITE
# 15  A1569518   M              25D    1.0 LBS            BLONDE
# 16  A1568373   F          8 Years   10.5 LBS             BLACK
# 17  A1570265   F          5 Years   47.5 LBS         WHITE TAN
# 18  A1570598   M          9 Years   13.0 LBS         RED WHITE
# 19  A1464021   S          5 Years   18.0 LBS              BUFF
# 20  A1570978   F         10 Years    6.9 LBS         BLACK TAN
# 21  A1570778   M           1 Year   14.0 LBS       BROWN BLACK
# 22  A1566935   M          3 Years   20.3 LBS       BROWN WHITE
# 23  A1570865   M          3 Years   13.2 LBS               RED
# 24  A1570105   M  1 Year 6 Months   16.2 LBS       WHITE BLACK
# 25  A1570493   M          2 Years   52.0 LBS       WHITE BROWN
# 26  A1570874   F          2 Years   58.4 LBS             BLACK
# 27  A1567904   S          4 Years   88.0 LBS         BLACK TAN
# 28  A1566279   M          6 Years   82.6 LBS       BROWN BLACK
# 29  A1566721   S  1 Year 7 Months   63.0 LBS         RED BLACK
# 30  A1570336   M           1 Year   62.0 LBS         BLACK TAN
# ..       ...  ..              ...        ...               ...
# 42  A1487390   N          2 Years   60.0 LBS        FAWN WHITE
# 43  A1545265   S          4 Years   54.0 LBS       BROWN WHITE
# 44  A1558941   N          2 Years   56.8 LBS        GRAY WHITE
# 45  A1560635   N          5 Years   61.0 LBS        BLUE WHITE
# 46  A1566233   N          3 Years   72.0 LBS        BLUE WHITE
# 47  A1563472   N   1 Year 2 Month   46.0 LBS       WHITE BLACK
# 48  A1564142   M          5 Years   71.0 LBS       BROWN WHITE
# 49  A1564184   N          3 Years   65.0 LBS        FAWN WHITE
# 50  A1568607   F          3 Years   53.0 LBS        BLUE WHITE
# 51  A1568806   F          4 Years   61.0 LBS              BLUE
# 52  A1569643   M          8 Years   96.0 LBS        BLUE WHITE
# 53  A1570861   M           1 Year   38.0 LBS       BLACK WHITE
# 54  A1569656   M          3 Years   83.0 LBS        WHITE GRAY
# 55  A1567053   F          2 Years   56.0 LBS  BR BRINDLE WHITE
# 56  A1567327   M   1 Year 1 Month   69.0 LBS         TAN WHITE
# 57  A1232105   N          8 Years   67.6 LBS        FAWN WHITE
# 58  A1541636   N          3 Years                   BLUE WHITE
# 59  A1570850   M          2 Years   15.0 LBS             WHITE
# 60  A1570429   F          3 Years   21.6 LBS             WHITE
# 61  A1568093   M   1 Year 1 Month    5.3 LBS         WHITE TAN
# 62  A1490547   M           3 Year   16.6 LBS             BLACK
# 63  A1570776   M          4 Years   19.0 LBS              GRAY
# 64  A1570936   M          9 Years   27.0 LBS       WHITE BROWN
# 65  A1570479   F          4 Years   12.0 LBS       BLACK WHITE
# 66  A1570699   M          2 Years   48.7 LBS        GRAY WHITE
# 67  A1570981   F        10 Months   42.0 LBS       WHITE BLACK
# 68  A1568134   N          4 Years   44.0 LBS             WHITE
# 69  A1569452   F          2 Years   50.0 LBS       BLACK WHITE
# 70  A1562494   N          4 Years  111.0 LBS          TRICOLOR
# 71  A1566722   N  1 Year 7 Months   17.0 LBS             WHITE
#
#                           Breed Intake Jurisdiction Intake Date
# 1                 ALASKAN HUSKY      HUNTINGTON BCH   4/11/2018
# 2               AM PIT BULL TER             ANAHEIM    4/6/2018
# 3               AUST CATTLE DOG      HUNTINGTON BCH    4/4/2018
# 4                     BOXER MIX             ANAHEIM   2/25/2018
# 5                 CAIRN TERRIER             ANAHEIM   4/12/2018
# 6                 CAIRN TERRIER           SANTA ANA   4/12/2018
# 7                  CHIHUAHUA SH           SANTA ANA   4/12/2018
# 8                  CHIHUAHUA SH             ANAHEIM   4/11/2018
# 9                  CHIHUAHUA SH           SANTA ANA   4/13/2018
# 10             CHIHUAHUA SH MIX        SANTA ANA CO   1/29/2018
# 11             CHIHUAHUA SH MIX           SANTA ANA    4/4/2018
# 12             CHIHUAHUA SH MIX           SANTA ANA    4/4/2018
# 13             CHIHUAHUA SH MIX           SANTA ANA    4/4/2018
# 14             CHIHUAHUA SH MIX           SANTA ANA    4/4/2018
# 15             CHIHUAHUA SH MIX           SANTA ANA    4/4/2018
# 16             CHIHUAHUA SH MIX             ANAHEIM   3/27/2018
# 17              CHINESE SHARPEI           FULLERTON    4/9/2018
# 18                  COCKER SPAN           SANTA ANA   4/11/2018
# 19                  COCKER SPAN              ORANGE    4/7/2018
# 20                DACHSHUND MIX           SANTA ANA   4/14/2018
# 21                DACHSHUND MIX           FULLERTON   4/12/2018
# 22    DACHSHUND LH CHIHUAHUA SH             ANAHEIM   3/17/2018
# 23     DACHSHUND LH COCKER SPAN           SANTA ANA   4/13/2018
# 24   DACHSHUND WH CAIRN TERRIER              ORANGE    4/7/2018
# 25                GERM SH POINT         LAKE FOREST   4/10/2018
# 26                GERM SHEPHERD           SANTA ANA   4/13/2018
# 27                GERM SHEPHERD           FULLERTON    4/5/2018
# 28                GERM SHEPHERD              ORANGE   3/12/2018
# 29  GERM SHEPHERD LABRADOR RETR             ANAHEIM    4/1/2018
# 30            GERM SHEPHERD MIX     OUT OF JURISDIC    4/9/2018
# ..                          ...                 ...         ...
# 42                     PIT BULL              ORANGE   2/14/2018
# 43                     PIT BULL         YORBA LINDA    2/3/2018
# 44                     PIT BULL             ANAHEIM   1/16/2018
# 45                     PIT BULL           SANTA ANA   1/28/2018
# 46                     PIT BULL           SANTA ANA   3/11/2018
# 47                     PIT BULL           SANTA ANA   2/17/2018
# 48                     PIT BULL           SANTA ANA   2/23/2018
# 49                     PIT BULL           SANTA ANA   2/23/2018
# 50                     PIT BULL             ANAHEIM   3/29/2018
# 51                     PIT BULL           SANTA ANA   3/30/2018
# 52                     PIT BULL           FULLERTON    4/5/2018
# 53        PIT BULL BASSET HOUND           SANTA ANA   4/13/2018
# 54                 PIT BULL MIX           FULLERTON    4/5/2018
# 55                 PIT BULL MIX           ORANGE CO   3/19/2018
# 56                 PIT BULL MIX             ANAHEIM   3/21/2018
# 57                 PIT BULL MIX       ORANGE CO FCC   1/22/2018
# 58                 PIT BULL MIX      HUNTINGTON BCH   4/12/2018
# 59                   POODLE MIN           SANTA ANA   4/13/2018
# 60                   POODLE MIN           SANTA ANA   4/10/2018
# 61               POODLE MIN MIX              TUSTIN   3/26/2018
# 62              RAT TERRIER MIX           SILVERADO   4/13/2018
# 63                SCHNAUZER MIN           SANTA ANA   4/12/2018
# 64                    SHIBA INU             ANAHEIM   4/13/2018
# 65                     SHIH TZU             ANAHEIM   4/10/2018
# 66               SIBERIAN HUSKY             ANAHEIM   4/11/2018
# 67               SIBERIAN HUSKY           SANTA ANA   4/14/2018
# 68               SIBERIAN HUSKY           SANTA ANA    4/9/2018
# 69               SIBERIAN HUSKY             ANAHEIM    4/4/2018
# 70               ST BERNARD RGH           FULLERTON   2/21/2018
# 71                WEST HIGHLAND             ANAHEIM   3/15/2018
#
# [71 rows x 8 columns]

# %%
dt.to_csv("found_list.csv")

# %%
len(img_list)
# Out:
# 70
